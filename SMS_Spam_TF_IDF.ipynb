# %% [markdown]
# <a href="https://colab.research.google.com/github/phamquocanh149/SMS_SPAM_Classification/blob/main/SMS_Spam_TF_IDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = "https://drive.google.com/uc?id=1qKjiO85UhWBaAQmqT8lyyuq09mXLkiym"

# Read the TSV (tab-separated) file
data = pd.read_csv(path, sep=',', engine='python', encoding='ISO-8859-1', header=None, names=['label', 'message', 'col3', 'col4', 'col5'])

print(data.head())
# Out:
#   label                                            message col3 col4 col5
# 0    v1                                                 v2  NaN  NaN  NaN
# 1   ham  Go until jurong point, crazy.. Available only ...  NaN  NaN  NaN
# 2   ham                      Ok lar... Joking wif u oni...  NaN  NaN  NaN
# 3  spam  Free entry in 2 a wkly comp to win FA Cup fina...  NaN  NaN  NaN
# 4   ham  U dun say so early hor... U c already then say...  NaN  NaN  NaN

# %%
data = data.drop(['col3', 'col4', 'col5'], axis = 1)
print(data.head())
# Out:
#   label                                            message
# 0    v1                                                 v2
# 1   ham  Go until jurong point, crazy.. Available only ...
# 2   ham                      Ok lar... Joking wif u oni...
# 3  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4   ham  U dun say so early hor... U c already then say...

# %%
X = data['message'][1:].tolist()
y = data['label'][1:].tolist()

# %%
print(X[0])
# Out:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...

# %%
print(y[0])
# Out:
# ham

# %%
print(len(X))
# Out:
# 5572

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
print(y)
# Out:
# [0 0 1 ... 0 0 0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=14,stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.9, max_features=3000)

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
print(X_train[:5])
print(X_test[:5])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14 stored elements and shape (5, 3000)>
#   Coords	Values
#   (0, 2969)	0.6016383213677934
#   (0, 1092)	0.6521701891997415
#   (0, 1888)	0.46119992907731155
#   (1, 1236)	0.501878564650425
#   (1, 1671)	0.864938093937612
#   (2, 1617)	1.0
#   (3, 2432)	0.6195408029718261
#   (3, 2662)	0.6372805980073682
#   (3, 2585)	0.4583040833948524
#   (4, 528)	0.4256620649583319
#   (4, 454)	0.3971449182291128
#   (4, 2980)	0.4147713349400227
#   (4, 369)	0.48223458875920355
#   (4, 2120)	0.5064605231373058
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 23 stored elements and shape (5, 3000)>
#   Coords	Values
#   (0, 770)	0.3673750992047917
#   (0, 1714)	0.5837188769608749
#   (0, 2434)	0.3612720553411932
#   (0, 2635)	0.6275271398062034
#   (1, 1236)	0.5778609133895343
#   (1, 1251)	0.8161352613241344
#   (2, 1990)	0.826915843226171
#   (2, 2853)	0.562325695857437
#   (4, 511)	0.30258161120748994
# ...

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)
print (y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9757847533632287
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       966
#            1       0.98      0.84      0.90       149
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.92      0.94      1115
# weighted avg       0.98      0.98      0.97      1115
